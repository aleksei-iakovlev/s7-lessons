# %%
root
 |-- event: struct (nullable = true)
 |    |-- admins: array (nullable = true)
 |    |    |-- element: long (containsNull = true)
 |    |-- channel_id: long (nullable = true)
 |    |-- datetime: string (nullable = true)
 |    |-- media: struct (nullable = true)
 |    |    |-- media_type: string (nullable = true)
 |    |    |-- src: string (nullable = true)
 |    |-- message: string (nullable = true)
 |    |-- message_channel_to: long (nullable = true)
 |    |-- message_from: long (nullable = true)
 |    |-- message_group: long (nullable = true)
 |    |-- message_id: long (nullable = true)
 |    |-- message_to: long (nullable = true)
 |    |-- message_ts: string (nullable = true)
 |    |-- reaction_from: string (nullable = true)
 |    |-- reaction_type: string (nullable = true)
 |    |-- subscription_channel: long (nullable = true)
 |    |-- tags: array (nullable = true)
 |    |    |-- element: string (containsNull = true)
 |    |-- user: string (nullable = true)
 |-- date: date (nullable = true)
 |-- event_type: string (nullable = true)
    
subscriptions:
 |-- event: struct (nullable = true)
 |    |-- datetime: string (nullable = true)
 |    |-- subscription_user: string (nullable = true)
 |    |-- user: string (nullable = true)
 |    |-- message: string (nullable = true)
 |    |-- message_from: long (nullable = true)
 |    |-- message_group: long (nullable = true)
 |    |-- message_id: long (nullable = true)
 |    |-- message_to: long (nullable = true)
 |    |-- message_ts: string (nullable = true)
 |    |-- admins: array (nullable = true)
 |    |    |-- element: long (containsNull = true)
 |    |-- channel_id: long (nullable = true)
 |    |-- media: struct (nullable = true)
 |    |    |-- media_type: string (nullable = true)
 |    |    |-- src: string (nullable = true)
 |    |-- message_channel_to: long (nullable = true)
 |    |-- reaction_from: string (nullable = true)
 |    |-- reaction_type: string (nullable = true)
 |    |-- subscription_channel: long (nullable = true)
 |    |-- tags: array (nullable = true)
 |    |    |-- element: string (containsNull = true)
 |-- date: date (nullable = true)
 |-- event_type: string (nullable = true)

# %%
df1 = spark.read.parquet('/user/s19290263/data/events/date=2022-05-25').where('event.channel_id is not null')
df1.count()
# Out:
# 1066637

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
import datetime
from pyspark.sql.window import Window
import sys



date = '2022-05-25'
days_count = 7
events_base_path = '/user/s19290263/data/events'
analytics_base_path = '/user/s19290263/analytics'
output_base_path = '/user/s19290263/data/analytics'

spark = SparkSession.builder \
    .master("yarn") \
    .appName(f"calculate_connection_interests_{date}_d{days_count}") \
    .getOrCreate()

def input_event_paths(date, depth):
    dt = datetime.datetime.strptime(date, '%Y-%m-%d')
    return [f"{events_base_path}/date={(dt - datetime.timedelta(days=x)).strftime('%Y-%m-%d')}" for x in
            range(depth)]

def calculate_connection_interests(date, depth, spark):

    paths = input_event_paths(date, depth)

    messages = spark.read\
        .option("basePath", events_base_path)\
        .parquet(*paths)\
        .where("""
                event_type = 'message'
                and event.message_to is not null
            """)

    directs = (
        messages
        .select(
            F.least(
                F.col("event.message_from"),
                F.col("event.message_to")
            ).alias("user_id_s"),
            F.greatest(
                F.col("event.message_from"),
                F.col("event.message_to")
            ).alias("user_id_r")
        )
        .distinct()
    )

    user_interests = spark.read.parquet(f"{analytics_base_path}/user_interests_d{depth}")

    user_likes = user_interests.select("user_id", F.col("like_tag_top_1"))\
        .union(user_interests.select("user_id", F.col("like_tag_top_2")))\
        .union(user_interests.select("user_id", F.col("like_tag_top_3")))\
        .toDF("user_id", "tag")
        
    window = Window.partitionBy("user_id").orderBy(F.desc("tag_count"), F.desc("tag"))

    likes = directs.join(user_likes, directs.user_id_r == user_likes.user_id, "left")\
        .drop("user_id_r")\
        .drop("user_id")\
        .withColumnRenamed("user_id_s", "user_id")\
        .groupBy("user_id", "tag")\
        .agg(F.count("tag").alias("tag_count"))\
        .withColumn("rank", F.row_number().over(window))\
        .where(F.col("rank") <= 3)\
        .groupBy("user_id").pivot("rank", [1, 2, 3]).agg(F.first("tag"))\
        .toDF("user_id", "direct_like_tag_top_1", "direct_like_tag_top_2", "direct_like_tag_top_3")

    user_dislikes = user_interests.select("user_id", F.col("dislike_tag_top_1").alias("tag"))\
        .union(user_interests.select("user_id", F.col("dislike_tag_top_2").alias("tag")))\
        .union(user_interests.select("user_id", F.col("dislike_tag_top_3").alias("tag")))

    dislikes = directs.join(user_dislikes, directs.user_id_r == user_dislikes.user_id, "left")\
        .drop("user_id_r")\
        .drop("user_id")\
        .withColumnRenamed("user_id_s", "user_id")\
        .groupBy("user_id", "tag")\
        .agg(F.count("tag").alias("tag_count"))\
        .withColumn("rank", F.row_number().over(window))\
        .where(F.col("rank") <= 3)\
        .groupBy("user_id").pivot("rank", [1, 2, 3]).agg(F.first("tag"))\
        .toDF("user_id", "direct_dislike_tag_top_1", "direct_dislike_tag_top_2", "direct_dislike_tag_top_3")

    subscriptions = spark.read\
        .option("mergeSchema", "true")\
        .parquet(events_base_path)\
        .where("event_type='subscription'")\
        .where(F.col("date") <= datetime.datetime.strptime(date, '%Y-%m-%d').date())\
        .select(F.col("event.user").alias("user_id"),\
            F.col("event.subscription_channel").alias("channel_id"))

    tags_verified = spark.read.parquet(f"{analytics_base_path}/verified_tags_candidates_d{depth}/date={date}")

    posts = spark.read\
        .option("basePath", events_base_path)\
        .parquet(*paths)\
        .where("event_type='message' and event.message_channel_to is not null")\
        .join(subscriptions, (F.col("event.message_channel_to") == F.col("channel_id")))\
        .select(F.col("event.user").alias("user_id"), F.explode(F.col("event.tags").alias("tag")))\
        .join(F.broadcast(tags_verified), "tag", "inner")

    channel_tags = posts\
        .groupBy("user_id", "tag")\
        .agg(F.count("*").alias("tag_count"))\
        .withColumn("rank", F.row_number().over(window))\
        .where(F.col("rank") <= 3)\
        .groupBy("user_id").pivot("rank", [1, 2, 3]).agg(F.first("tag"))\
        .toDF("user_id", "sub_verified_tag_top_1", "sub_verified_tag_top_2", "sub_verified_tag_top_3")        

    connection_interests = likes.join(dislikes, "user_id", "full").join(channel_tags, "user_id", "full")
    connection_interests.write.mode("overwrite").parquet(f"{output_base_path}/connection_interests_d{depth}/date={date}")
        
    print("messages:", messages.count())
    print("directs:", directs.count())
    print("user_likes:", user_likes.count())
    print("subscriptions:", subscriptions.count())
    print("channel_messages:", channel_messages.count())
    print("channel_tags:", channel_tags.count())
    print("likes users:", likes.select("user_id").distinct().count())
    print("channel users:", channel_tags.select("user_id").distinct().count())
    print("result users:", connection_interests.select("user_id").distinct().count())

    return None

calculate_connection_interests(date, days_count, spark)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[24], line 128
#     124     print("result users:", connection_interests.select("user_id").distinct().count())
#     126     return None
# --> 128 calculate_connection_interests(date, days_count, spark)
#
# Cell In[24], line 97, in calculate_connection_interests(date, depth, spark)
#      87 subscriptions = spark.read\
#      88     .option("mergeSchema", "true")\
#      89     .parquet(events_base_path)\
#    (...)
#      92     .select(F.col("event.user").alias("user_id"),\
#      93         F.col("event.subscription_channel").alias("channel_id"))
#      95 tags_verified = spark.read.parquet(f"{analytics_base_path}/verified_tags_candidates_d{depth}/date={date}")
# ---> 97 channel_messages = spark.read\
#      98     .option("basePath", events_base_path)\
#      99     .parquet(*paths)\
#     100     .where("event_type='message' and event.message_channel_to is not null")\
#     101     .join(subscriptions, (F.col("event.message_channel_to") == F.col("channel_id")))\
#     102     .select(F.col("event.user").alias("user_id"), F.explode(F.col("event.tags").alias("tag")))\
#     103     .join(F.broadcast(tags_verified), "tag", "inner")
#     105 channel_tags = channel_messages\
#     106     .groupBy("user_id", "tag")\
#     107     .agg(F.count("*").alias("tag_count"))\
#    (...)
#     110     .groupBy("user_id").pivot("rank", [1, 2, 3]).agg(F.first("tag"))\
#     111     .toDF("user_id", "sub_verified_tag_top_1", "sub_verified_tag_top_2", "sub_verified_tag_top_3")
#     113 connection_interests = likes.join(dislikes, "user_id", "full").join(channel_tags, "user_id", "full")
#
# File /opt/spark/python/pyspark/sql/dataframe.py:1539, in DataFrame.join(self, other, on, how)
#    1537         on = self._jseq([])
#    1538     assert isinstance(how, str), "how should be a string"
# -> 1539     jdf = self._jdf.join(other._jdf, on, how)
#    1540 return DataFrame(jdf, self.sparkSession)
#
# File /opt/conda/lib/python3.8/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /opt/spark/python/pyspark/sql/utils.py:196, in capture_sql_exception.<locals>.deco(*a, **kw)
#     192 converted = convert_exception(e.java_exception)
#     193 if not isinstance(converted, UnknownException):
#     194     # Hide where the exception came from that shows a non-Pythonic
#     195     # JVM exception message.
# --> 196     raise converted from None
#     197 else:
#     198     raise
#
# AnalysisException: USING column `tag` cannot be resolved on the left side of the join. The left-side columns: [user_id, col]

# %%
# !hdfs dfs -ls /user/s19290263/data/analytics/connection_interests_d7
# Out:
# ls: `/user/s19290263/data/analytics/connection_interests_d7': No such file or directory

# %%
df = spark.read.parquet('/user/s19290263/data/analytics/connection_interests_d7/date=2022-05-25').where("user_id == '1806'")
df.show()
# Out:
# +-------+---------------------+---------------------+---------------------+------------------------+------------------------+------------------------+----------------------+----------------------+----------------------+
# |user_id|direct_like_tag_top_1|direct_like_tag_top_2|direct_like_tag_top_3|direct_dislike_tag_top_1|direct_dislike_tag_top_2|direct_dislike_tag_top_3|sub_verified_tag_top_1|sub_verified_tag_top_2|sub_verified_tag_top_3|
# +-------+---------------------+---------------------+---------------------+------------------------+------------------------+------------------------+----------------------+----------------------+----------------------+
# |   1806|                Чулан|            Транспорт|   DIY или Сделай сам|                 watches|             switzerland|                sean-rad|                 Чулан|                  null|                  null|
# +-------+---------------------+---------------------+---------------------+------------------------+------------------------+------------------------+----------------------+----------------------+----------------------+

# %%
df1 = spark.read.parquet('/user/master/data/auth/5.3.1/connection_interests_d7_test/date=2022-05-25')
df1.show(20, False)
# Out:
# +-------+---------------------------+----------------------------+----------------------------+-------------------------+----------------------------------+------------------------+----------------------+----------------------+----------------------+
# |user_id|direct_like_tag_top_1      |direct_like_tag_top_2       |direct_like_tag_top_3       |direct_dislike_tag_top_1 |direct_dislike_tag_top_2          |direct_dislike_tag_top_3|sub_verified_tag_top_1|sub_verified_tag_top_2|sub_verified_tag_top_3|
# +-------+---------------------------+----------------------------+----------------------------+-------------------------+----------------------------------+------------------------+----------------------+----------------------+----------------------+
# |1806   |Чулан                      |DIY или Сделай сам          |Транспорт                   |Разработка под MacOS     |switzerland                       |sean-rad                |null                  |null                  |null                  |
# |8075   |reddit                     |Исследования и прогнозы в IT|weddings                    |Разработка под Android   |Программирование микроконтроллеров|videoslam               |null                  |null                  |null                  |
# |9715   |null                       |null                        |null                        |null                     |null                              |null                    |apps                  |null                  |null                  |
# |10959  |Информационная безопасность|Физика                      |Разработка под Windows      |Разработка под e-commerce|Проектирование и рефакторинг      |quora                   |null                  |null                  |null                  |
# |13098  |Разработка под iOS         |Разработка под MacOS        |Разработка веб-сайтов       |Копирайт                 |gadgets-podcast                   |Разработка игр          |null                  |null                  |null                  |
# |13723  |vkontakte                  |vk-com                      |telegram                    |Финансы в IT             |Криптовалюты                      |wechat                  |null                  |null                  |null                  |
# |25479  |null                       |null                        |null                        |null                     |null                              |null                    |apps                  |null                  |null                  |
# |31703  |Экология                   |Транспорт                   |paypal                      |robinhood                |Управление медиа                  |Разработка игр          |null                  |null                  |null                  |
# |33013  |Информационная безопасность|toys-to-life                |social                      |Облачные вычисления      |twitter                           |twice                   |null                  |null                  |null                  |
# |38543  |Чулан                      |Финансы в IT                |Звук                        |Разработка под iOS       |Разработка веб-сайтов             |video                   |null                  |null                  |null                  |
# |39094  |null                       |null                        |null                        |null                     |null                              |null                    |autism                |null                  |null                  |
# |43367  |Чулан                      |Социальные сети и сообщества|Софт                        |Разработка под MacOS     |xbox-one                          |xbox                    |null                  |null                  |null                  |
# |50157  |Чулан                      |Финансы в IT                |Исследования и прогнозы в IT|secure-islands           |pleo-io                           |mergers-and-acquistions |null                  |null                  |null                  |
# |60882  |null                       |null                        |null                        |null                     |null                              |null                    |Программирование      |null                  |null                  |
# |61251  |Гаджеты                    |social                      |Управление e-commerce       |recruitment              |minibar                           |PHP                     |null                  |null                  |null                  |
# |62419  |Чулан                      |sports                      |mobile                      |Умный дом                |Разработка веб-сайтов             |Интернет вещей          |null                  |null                  |null                  |
# |63710  |Чулан                      |Сетевые технологии          |Сетевое оборудование        |Типографика              |search                            |professional-networking |null                  |null                  |null                  |
# |64757  |null                       |null                        |null                        |null                     |null                              |null                    |Программирование      |null                  |null                  |
# |67148  |null                       |null                        |null                        |null                     |null                              |null                    |Программирование      |null                  |null                  |
# |74185  |Электроника для начинающих |Чулан                       |trulia                      |Смартфоны                |Гаджеты                           |Венчурные инвестиции    |null                  |null                  |null                  |
# +-------+---------------------------+----------------------------+----------------------------+-------------------------+----------------------------------+------------------------+----------------------+----------------------+----------------------+
# only showing top 20 rows

# %%
df1 = spark.read.parquet('/user/s19290263/analytics/verified_tags_candidates_d7/date=2022-05-25')
df1.show()
# Out:
# +--------------------+---------------+----------+
# |                 tag|suggested_count|      date|
# +--------------------+---------------+----------+
# |               Чулан|            471|2022-05-25|
# |            Finelook|            129|2022-05-25|
# |         IT-компании|            172|2022-05-25|
# |Разработка веб-са...|            122|2022-05-25|
# |   Научно-популярное|            116|2022-05-25|
# +--------------------+---------------+----------+
